# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
data = "Voter Turnout.csv"

# %%
orig_voter = pd.read_csv(data, encoding="ISO-8859-1")
orig_voter.head()
# Out:
#    voter_id_org      STATE_ID           city  ward pct   name_last name_first  \
# 0       2787583  OH0024229548      MAPLE HTS     6   B  MCNICHOLAS   JOSEFINA
# 1       2787640  OH0024229841     SHAKER HTS     0   I     CROWLEY  NATHANIEL
# 2       2787790  OH0024231522     SHAKER HTS     0   N      DUNCAN      EDITH
# 3       2788233  OH0024237261  BROADVIEW HTS     4   A  KITZBERGER     STEVEN
# 4       2788262  OH0024237638          PARMA     1   C       SMITH     GLORIA
#
#   name_middle name_suffix Status  ... S_02_06_2007 S_08_08_2006 P_05_02_2006  \
# 0     BANHAON         NaN      A  ...          NaN          NaN          NaN
# 1     MANOGUE         NaN      A  ...          NaN          NaN          NaN
# 2           E         NaN      A  ...          NaN          NaN          NaN
# 3           B         NaN      A  ...          NaN          NaN          NaN
# 4           R         NaN      A  ...          NaN          NaN          NaN
#
#    S_02_07_2006       scd     CONG     HSE     SEN      JUD     CCD
# 0           NaN  MPHT CSD  CONG 11  HSE 12  SEN 25  GAR MCD  CCD 08
# 1           NaN  SKHT CSD  CONG 11  HSE 09  SEN 21  SHH MCD  CCD 09
# 2           NaN  SKHT CSD  CONG 11  HSE 09  SEN 21  SHH MCD  CCD 09
# 3           NaN  NROY CSD  CONG 11  HSE 06  SEN 24  PAR MCD  CCD 06
# 4           NaN  PRMA CSD  CONG 16  HSE 15  SEN 23  PAR MCD  CCD 04
#
# [5 rows x 90 columns]

# %%
col_drop_voter = orig_voter[['voter_id_org','city','party','birth_date', 'G_11_06_2018','G_11_07_2017', 'G_11_08_2016'
,'G_11_03_2015', 'G_11_04_2014', 'G_11_05_2013', 'G_11_06_2012', 'G_11_08_2011','G_11_02_2010', 'G_11_03_2009', 'G_11_04_2008', 'G_11_06_2007','G_11_07_2006']]

# %%
col_drop_voter.head()
# Out:
#    voter_id_org           city  party  birth_date G_11_06_2018 G_11_07_2017  \
# 0       2787583      MAPLE HTS  NOPTY        1953            Y          NaN
# 1       2787640     SHAKER HTS  NOPTY        1999            Y          NaN
# 2       2787790     SHAKER HTS    DEM        1999            Y          NaN
# 3       2788233  BROADVIEW HTS  NOPTY        1983            Y          NaN
# 4       2788262          PARMA  NOPTY        1935            Y          NaN
#
#   G_11_08_2016 G_11_03_2015 G_11_04_2014 G_11_05_2013 G_11_06_2012  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   G_11_08_2011 G_11_02_2010 G_11_03_2009 G_11_04_2008 G_11_06_2007  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   G_11_07_2006
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
#col_drop_voter.to_csv('Voter_Turnout_Col_Drop.csv')

# %%
data2 = "Voter_Turnout_Col_Drop.csv"

# %%
voter_turnout = pd.read_csv(data2, encoding="ISO-8859-1")
voter_turnout_df = pd.DataFrame(voter_turnout)
voter_turnout_df.head()
# Out:
#    Unnamed: 0  voter_id_org           city  party  birth_date G_11_06_2018  \
# 0           0       2787583      MAPLE HTS  NOPTY        1953            Y
# 1           1       2787640     SHAKER HTS  NOPTY        1999            Y
# 2           2       2787790     SHAKER HTS    DEM        1999            Y
# 3           3       2788233  BROADVIEW HTS  NOPTY        1983            Y
# 4           4       2788262          PARMA  NOPTY        1935            Y
#
#   G_11_07_2017 G_11_08_2016 G_11_03_2015 G_11_04_2014 G_11_05_2013  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   G_11_06_2012 G_11_08_2011 G_11_02_2010 G_11_03_2009 G_11_04_2008  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   G_11_06_2007 G_11_07_2006
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN

# %%
#voter_turnout_df.drop("Unnamed: 0", axis = 1, inplace=True)
#voter_turnout_df.head()

# %%
voter_turnout_df.count()
# Out:
# Unnamed: 0      875473
# voter_id_org    875473
# city            875473
# party           875473
# birth_date      875473
# G_11_06_2018    488101
# G_11_07_2017    264600
# G_11_08_2016    576133
# G_11_03_2015    295753
# G_11_04_2014    310251
# G_11_05_2013    225157
# G_11_06_2012    534659
# G_11_08_2011    308363
# G_11_02_2010    331856
# G_11_03_2009    287163
# G_11_04_2008    464621
# G_11_06_2007    141839
# G_11_07_2006    308436
# dtype: int64

# %%
voter_turnout_df.fillna(value = 'N', inplace=True)
voter_turnout_df.head(100)
# Out:
#     Unnamed: 0  voter_id_org              city  party  birth_date  \
# 0            0       2787583         MAPLE HTS  NOPTY        1953
# 1            1       2787640        SHAKER HTS  NOPTY        1999
# 2            2       2787790        SHAKER HTS    DEM        1999
# 3            3       2788233     BROADVIEW HTS  NOPTY        1983
# 4            4       2788262             PARMA  NOPTY        1935
# 5            5       2788319         CLEVELAND  NOPTY        1996
# 6            6       2788326         CLEVELAND  NOPTY        1999
# 7            7       2788462     CLEVELAND HTS  NOPTY        1989
# 8            8       2788712     CHAGRIN FALLS  NOPTY        1938
# 9            9       2788726       BEDFORD HTS  NOPTY        1993
# 10          10       2788755     NORTH OLMSTED  NOPTY        1957
# 11          11       2788912          WESTLAKE  NOPTY        1930
# 12          12       2789055      STRONGSVILLE  NOPTY        1999
# 13          13       2583720     CLEVELAND HTS  NOPTY        1992
# 14          14       2583855          LAKEWOOD  NOPTY        1991
# 15          15       2583906         CLEVELAND  NOPTY        1963
# 16          16       2584006         CLEVELAND  NOPTY        1989
# 17          17       2584020         CLEVELAND  NOPTY        1961
# 18          18       2584156      SOUTH EUCLID  NOPTY        1979
# 19          19       2584506            EUCLID  NOPTY        1974
# 20          20       2584656      STRONGSVILLE  NOPTY        1959
# 21          21       2584755       BRECKSVILLE  NOPTY        1934
# 22          22       2584856  WARRENSVILLE HTS    DEM        1950
# 23          23       2584905      GARFIELD HTS  NOPTY        1973
# 24          24       2584942         CLEVELAND  NOPTY        1993
# 25          25       2585005         CLEVELAND  NOPTY        1987
# 26          26       2789155         CLEVELAND  NOPTY        1957
# 27          27       2789255          BROOKLYN  NOPTY        1998
# 28          28       2789305       BEDFORD HTS  NOPTY        1949
# 29          29       2789555             PARMA  NOPTY        1970
# ..         ...           ...               ...    ...         ...
# 70          70       2558923         CLEVELAND  NOPTY        1993
# 71          71       2559030         CLEVELAND    REP        1991
# 72          72       2559066     BROADVIEW HTS    DEM        1982
# 73          73       2559116     BROADVIEW HTS  NOPTY        1968
# 74          74       2559159      STRONGSVILLE  NOPTY        1994
# 75          75       2559173            EUCLID  NOPTY        1991
# 76          76       2559223    EAST CLEVELAND    DEM        1954
# 77          77       2559316         CLEVELAND  NOPTY        1979
# 78          78       2353874         CLEVELAND  NOPTY        1974
# 79          79       2353959      RICHMOND HTS  NOPTY        1990
# 80          80       2354123    EAST CLEVELAND  NOPTY        1976
# 81          81       2354309         MAPLE HTS  NOPTY        1990
# 82          82       2354660    EAST CLEVELAND  NOPTY        1987
# 83          83       2354845         CLEVELAND  NOPTY        1962
# 84          84       2354895         PARMA HTS  NOPTY        1989
# 85          85       2354959         CLEVELAND  NOPTY        1988
# 86          86       2355010      MAYFIELD HTS  NOPTY        1969
# 87          87       2355095         CLEVELAND    DEM        1979
# 88          88       2355145     CLEVELAND HTS  NOPTY        1989
# 89          89       2812279          LAKEWOOD  NOPTY        1965
# 90          90       2812329     BROADVIEW HTS  NOPTY        1999
# 91          91       2812223      HIGHLAND HTS  NOPTY        1955
# 92          92       2812440       SEVEN HILLS  NOPTY        1999
# 93          93       2812840          LAKEWOOD  NOPTY        1990
# 94          94       2812908         LYNDHURST  NOPTY        1998
# 95          95       2812955        SHAKER HTS  NOPTY        1972
# 96          96       2813057     NORTH OLMSTED  NOPTY        2000
# 97          97       2813091     NORTH OLMSTED  NOPTY        1999
# 98          98       2813376             SOLON  NOPTY        1990
# 99          99       2813559     CLEVELAND HTS    DEM        1993
#
#    G_11_06_2018 G_11_07_2017 G_11_08_2016 G_11_03_2015 G_11_04_2014  \
# 0             Y            N            N            N            N
# 1             Y            N            N            N            N
# 2             Y            N            N            N            N
# 3             Y            N            N            N            N
# 4             Y            N            N            N            N
# 5             Y            N            N            N            N
# 6             Y            N            N            N            N
# 7             Y            N            N            N            N
# 8             Y            N            N            N            N
# 9             Y            N            N            N            N
# 10            Y            N            N            N            N
# 11            Y            N            N            N            N
# 12            Y            N            N            N            N
# 13            N            N            N            N            N
# 14            Y            N            Y            N            N
# 15            N            N            Y            N            N
# 16            N            N            N            N            N
# 17            N            N            Y            N            N
# 18            Y            Y            Y            Y            Y
# 19            Y            N            Y            N            N
# 20            N            N            N            N            N
# 21            N            N            Y            N            N
# 22            Y            Y            Y            N            Y
# 23            N            N            Y            N            N
# 24            Y            N            Y            N            N
# 25            N            N            N            N            N
# 26            Y            Y            N            N            N
# 27            N            N            N            N            N
# 28            Y            N            N            N            N
# 29            Y            N            N            N            N
# ..          ...          ...          ...          ...          ...
# 70            N            N            N            N            N
# 71            Y            N            Y            N            Y
# 72            Y            Y            Y            Y            N
# 73            Y            Y            Y            Y            Y
# 74            Y            Y            Y            Y            Y
# 75            N            N            N            N            N
# 76            N            N            Y            N            N
# 77            N            N            Y            N            N
# 78            Y            N            Y            N            N
# 79            N            N            N            N            N
# 80            N            N            N            N            N
# 81            N            N            N            N            N
# 82            N            N            Y            N            N
# 83            N            N            N            N            N
# 84            N            N            Y            N            N
# 85            Y            N            N            N            N
# 86            Y            N            Y            Y            Y
# 87            Y            N            Y            Y            N
# 88            Y            N            Y            N            N
# 89            Y            N            N            N            N
# 90            Y            N            N            N            N
# 91            Y            N            N            N            N
# 92            Y            N            N            N            N
# 93            Y            N            N            N            N
# 94            Y            N            N            N            N
# 95            Y            N            N            N            N
# 96            Y            N            N            N            N
# 97            Y            N            N            N            N
# 98            Y            N            N            N            N
# 99            Y            N            N            N            N
#
#    G_11_05_2013 G_11_06_2012 G_11_08_2011 G_11_02_2010 G_11_03_2009  \
# 0             N            N            N            N            N
# 1             N            N            N            N            N
# 2             N            N            N            N            N
# 3             N            N            N            N            N
# 4             N            N            N            N            N
# 5             N            N            N            N            N
# 6             N            N            N            N            N
# 7             N            N            N            N            N
# 8             N            N            N            N            N
# 9             N            N            N            N            N
# 10            N            N            N            N            N
# 11            N            N            N            N            N
# 12            N            N            N            N            N
# 13            N            Y            N            N            N
# 14            N            Y            N            N            N
# 15            N            N            N            N            N
# 16            N            Y            N            N            N
# 17            N            N            N            N            N
# 18            Y            Y            N            N            N
# 19            N            Y            N            N            N
# 20            N            Y            N            N            N
# 21            N            Y            N            N            N
# 22            N            Y            N            N            N
# 23            N            Y            N            N            N
# 24            N            Y            N            N            N
# 25            N            Y            N            N            N
# 26            N            N            N            N            N
# 27            N            N            N            N            N
# 28            N            N            N            N            N
# 29            N            N            N            N            N
# ..          ...          ...          ...          ...          ...
# 70            N            Y            N            N            N
# 71            N            Y            N            N            N
# 72            N            Y            N            N            N
# 73            N            Y            N            N            N
# 74            Y            Y            N            N            N
# 75            N            Y            N            N            N
# 76            N            Y            N            N            N
# 77            N            Y            N            N            N
# 78            N            N            N            N            N
# 79            N            Y            N            N            Y
# 80            N            Y            N            N            N
# 81            N            Y            Y            N            N
# 82            N            N            N            N            N
# 83            N            Y            N            N            Y
# 84            N            N            N            N            N
# 85            N            Y            N            N            N
# 86            N            Y            Y            N            Y
# 87            N            Y            N            N            N
# 88            N            Y            Y            N            N
# 89            N            N            N            N            N
# 90            N            N            N            N            N
# 91            N            N            N            N            N
# 92            N            N            N            N            N
# 93            N            N            N            N            N
# 94            N            N            N            N            N
# 95            N            N            N            N            N
# 96            N            N            N            N            N
# 97            N            N            N            N            N
# 98            N            N            N            N            N
# 99            N            N            N            N            N
#
#    G_11_04_2008 G_11_06_2007 G_11_07_2006
# 0             N            N            N
# 1             N            N            N
# 2             N            N            N
# 3             N            N            N
# 4             N            N            N
# 5             N            N            N
# 6             N            N            N
# 7             N            N            N
# 8             N            N            N
# 9             N            N            N
# 10            N            N            N
# 11            N            N            N
# 12            N            N            N
# 13            N            N            N
# 14            N            N            N
# 15            N            N            N
# 16            N            N            N
# 17            N            N            N
# 18            N            N            N
# 19            N            N            N
# 20            N            N            N
# 21            N            N            N
# 22            N            N            N
# 23            N            N            N
# 24            N            N            N
# 25            N            N            N
# 26            N            N            N
# 27            N            N            N
# 28            N            N            N
# 29            N            N            N
# ..          ...          ...          ...
# 70            N            N            N
# 71            N            N            N
# 72            N            N            N
# 73            N            N            N
# 74            N            N            N
# 75            N            N            N
# 76            N            N            N
# 77            N            N            N
# 78            N            N            N
# 79            Y            N            N
# 80            Y            N            N
# 81            Y            N            N
# 82            Y            N            N
# 83            Y            N            N
# 84            N            N            N
# 85            Y            N            N
# 86            N            N            N
# 87            Y            N            N
# 88            Y            N            N
# 89            N            N            N
# 90            N            N            N
# 91            N            N            N
# 92            N            N            N
# 93            N            N            N
# 94            N            N            N
# 95            N            N            N
# 96            N            N            N
# 97            N            N            N
# 98            N            N            N
# 99            N            N            N
#
# [100 rows x 18 columns]

# %%
voter_turnout_df.count()
# Out:
# Unnamed: 0      875473
# voter_id_org    875473
# city            875473
# party           875473
# birth_date      875473
# G_11_06_2018    875473
# G_11_07_2017    875473
# G_11_08_2016    875473
# G_11_03_2015    875473
# G_11_04_2014    875473
# G_11_05_2013    875473
# G_11_06_2012    875473
# G_11_08_2011    875473
# G_11_02_2010    875473
# G_11_03_2009    875473
# G_11_04_2008    875473
# G_11_06_2007    875473
# G_11_07_2006    875473
# dtype: int64

# %%
#voter_turnout_df.set_index('voter_id_org', inplace=True)
#voter_turnout_df.head()

# %%
    
voter_df = voter_turnout_df[['voter_id_org','city','party','birth_date']]
voter_df.set_index('voter_id_org', inplace=True)
voter_df.head()
# Out:
#                        city  party  birth_date
# voter_id_org
# 2787583           MAPLE HTS  NOPTY        1953
# 2787640          SHAKER HTS  NOPTY        1999
# 2787790          SHAKER HTS    DEM        1999
# 2788233       BROADVIEW HTS  NOPTY        1983
# 2788262               PARMA  NOPTY        1935

# %%
voter_df.to_csv('Voters.csv')

# %%
nov_18 = voter_turnout_df[['voter_id_org','G_11_06_2018']]
nov_18.head()
# Out:
#    voter_id_org G_11_06_2018
# 0       2787583            Y
# 1       2787640            Y
# 2       2787790            Y
# 3       2788233            Y
# 4       2788262            Y

# %%
nov_18 = nov_18.assign(election = 'Nov 18 Election')
nov_18.head()
# Out:
#    voter_id_org G_11_06_2018         election
# 0       2787583            Y  Nov 18 Election
# 1       2787640            Y  Nov 18 Election
# 2       2787790            Y  Nov 18 Election
# 3       2788233            Y  Nov 18 Election
# 4       2788262            Y  Nov 18 Election

# %%
nov_18 = nov_18[['voter_id_org','election','G_11_06_2018']]
nov_18.head()
# Out:
#    voter_id_org         election G_11_06_2018
# 0       2787583  Nov 18 Election            Y
# 1       2787640  Nov 18 Election            Y
# 2       2787790  Nov 18 Election            Y
# 3       2788233  Nov 18 Election            Y
# 4       2788262  Nov 18 Election            Y

# %%
nov_18.columns = ['voter_id', 'election', 'voted']
nov_18.head()
# Out:
#    voter_id         election voted
# 0   2787583  Nov 18 Election     Y
# 1   2787640  Nov 18 Election     Y
# 2   2787790  Nov 18 Election     Y
# 3   2788233  Nov 18 Election     Y
# 4   2788262  Nov 18 Election     Y

# %%
nov_18.set_index('voter_id', inplace=True)
#nov_18.head()

# %%
nov_17 = voter_turnout_df[['voter_id_org','G_11_07_2017']]
nov_17 = nov_17.assign(election = 'Nov 17 Election')
nov_17 = nov_17[['voter_id_org','election','G_11_07_2017']]
nov_17.columns = ['voter_id', 'election', 'voted']
nov_17.set_index('voter_id', inplace=True)
nov_17.head()
# Out:
#                  election voted
# voter_id
# 2787583   Nov 17 Election     N
# 2787640   Nov 17 Election     N
# 2787790   Nov 17 Election     N
# 2788233   Nov 17 Election     N
# 2788262   Nov 17 Election     N

# %%
nov_16 = voter_turnout_df[['voter_id_org','G_11_08_2016']]
nov_16 = nov_16.assign(election = 'Nov 16 Election')
nov_16 = nov_16[['voter_id_org','election','G_11_08_2016']]
nov_16.columns = ['voter_id', 'election', 'voted']
nov_16.set_index('voter_id', inplace=True)
nov_16.head()
# Out:
#                  election voted
# voter_id
# 2787583   Nov 16 Election     N
# 2787640   Nov 16 Election     N
# 2787790   Nov 16 Election     N
# 2788233   Nov 16 Election     N
# 2788262   Nov 16 Election     N

# %%
nov_15 = voter_turnout_df[['voter_id_org','G_11_03_2015']]
nov_15 = nov_15.assign(election = 'Nov 15 Election')
nov_15 = nov_15[['voter_id_org','election','G_11_03_2015']]
nov_15.columns = ['voter_id', 'election', 'voted']
nov_15.set_index('voter_id', inplace=True)
nov_15.head()
# Out:
#                  election voted
# voter_id
# 2787583   Nov 15 Election     N
# 2787640   Nov 15 Election     N
# 2787790   Nov 15 Election     N
# 2788233   Nov 15 Election     N
# 2788262   Nov 15 Election     N

# %%
nov_14 = voter_turnout_df[['voter_id_org','G_11_04_2014']]
nov_14 = nov_14.assign(election = 'Nov 14 Election')
nov_14 = nov_14[['voter_id_org','election','G_11_04_2014']]
nov_14.columns = ['voter_id', 'election', 'voted']
nov_14.set_index('voter_id', inplace=True)
nov_14.head()
# Out:
#                  election voted
# voter_id
# 2787583   Nov 14 Election     N
# 2787640   Nov 14 Election     N
# 2787790   Nov 14 Election     N
# 2788233   Nov 14 Election     N
# 2788262   Nov 14 Election     N

# %%
nov_13 = voter_turnout_df[['voter_id_org','G_11_05_2013']]
nov_13 = nov_13.assign(election = 'Nov 13 Election')
nov_13 = nov_13[['voter_id_org','election','G_11_05_2013']]
nov_13.columns = ['voter_id', 'election', 'voted']
nov_13.set_index('voter_id', inplace=True)
nov_13.head()
# Out:
#                  election voted
# voter_id
# 2787583   Nov 13 Election     N
# 2787640   Nov 13 Election     N
# 2787790   Nov 13 Election     N
# 2788233   Nov 13 Election     N
# 2788262   Nov 13 Election     N

# %%
nov_12 = voter_turnout_df[['voter_id_org','G_11_06_2012']]
nov_12 = nov_12.assign(election = 'Nov 12 Election')
nov_12 = nov_12[['voter_id_org','election','G_11_06_2012']]
nov_12.columns = ['voter_id', 'election', 'voted']
nov_12.set_index('voter_id', inplace=True)
nov_12.head()
# Out:
#                  election voted
# voter_id
# 2787583   Nov 12 Election     N
# 2787640   Nov 12 Election     N
# 2787790   Nov 12 Election     N
# 2788233   Nov 12 Election     N
# 2788262   Nov 12 Election     N

# %%
nov_11 = voter_turnout_df[['voter_id_org','G_11_08_2011']]
nov_11 = nov_11.assign(election = 'Nov 11 Election')
nov_11 = nov_11[['voter_id_org','election','G_11_08_2011']]
nov_11.columns = ['voter_id', 'election', 'voted']
nov_11.set_index('voter_id', inplace=True)
nov_11.head()
# Out:
#                  election voted
# voter_id
# 2787583   Nov 11 Election     N
# 2787640   Nov 11 Election     N
# 2787790   Nov 11 Election     N
# 2788233   Nov 11 Election     N
# 2788262   Nov 11 Election     N

# %%
nov_10 = voter_turnout_df[['voter_id_org','G_11_02_2010']]
nov_10 = nov_10.assign(election = 'Nov 10 Election')
nov_10 = nov_10[['voter_id_org','election','G_11_02_2010']]
nov_10.columns = ['voter_id', 'election', 'voted']
nov_10.set_index('voter_id', inplace=True)
nov_10.head()
# Out:
#                  election voted
# voter_id
# 2787583   Nov 10 Election     N
# 2787640   Nov 10 Election     N
# 2787790   Nov 10 Election     N
# 2788233   Nov 10 Election     N
# 2788262   Nov 10 Election     N

# %%
nov_09 = voter_turnout_df[['voter_id_org','G_11_03_2009']]
nov_09 = nov_09.assign(election = 'Nov 09 Election')
nov_09 = nov_09[['voter_id_org','election','G_11_03_2009']]
nov_09.columns = ['voter_id', 'election', 'voted']
nov_09.set_index('voter_id', inplace=True)
nov_09.head()
# Out:
#                  election voted
# voter_id
# 2787583   Nov 09 Election     N
# 2787640   Nov 09 Election     N
# 2787790   Nov 09 Election     N
# 2788233   Nov 09 Election     N
# 2788262   Nov 09 Election     N

# %%
nov_08 = voter_turnout_df[['voter_id_org','G_11_04_2008']]
nov_08 = nov_08.assign(election = 'Nov 08 Election')
nov_08 = nov_08[['voter_id_org','election','G_11_04_2008']]
nov_08.columns = ['voter_id', 'election', 'voted']
nov_08.set_index('voter_id', inplace=True)
nov_08.head()
# Out:
#                  election voted
# voter_id
# 2787583   Nov 08 Election     N
# 2787640   Nov 08 Election     N
# 2787790   Nov 08 Election     N
# 2788233   Nov 08 Election     N
# 2788262   Nov 08 Election     N

# %%
nov_07 = voter_turnout_df[['voter_id_org','G_11_06_2007']]
nov_07 = nov_07.assign(election = 'Nov 07 Election')
nov_07 = nov_07[['voter_id_org','election','G_11_06_2007']]
nov_07.columns = ['voter_id', 'election', 'voted']
nov_07.set_index('voter_id', inplace=True)
nov_07.head()
# Out:
#                  election voted
# voter_id
# 2787583   Nov 07 Election     N
# 2787640   Nov 07 Election     N
# 2787790   Nov 07 Election     N
# 2788233   Nov 07 Election     N
# 2788262   Nov 07 Election     N

# %%
nov_06 = voter_turnout_df[['voter_id_org','G_11_07_2006']]
nov_06 = nov_06.assign(election = 'Nov 06 Election')
nov_06 = nov_06[['voter_id_org','election','G_11_07_2006']]
nov_06.columns = ['voter_id', 'election', 'voted']
nov_06.set_index('voter_id', inplace=True)
nov_06.head()
# Out:
#                  election voted
# voter_id
# 2787583   Nov 06 Election     N
# 2787640   Nov 06 Election     N
# 2787790   Nov 06 Election     N
# 2788233   Nov 06 Election     N
# 2788262   Nov 06 Election     N

# %%
dfs = [nov_06,nov_07, nov_08, nov_09, nov_10, nov_11,nov_12,nov_13, nov_14, nov_15, nov_16, nov_17, nov_18]

# %%
merged = pd.concat(dfs)
#merged.head(100)
#merged.count()

# %%
final = merged.sort_values(by=['voter_id', 'election'], ascending=[True, False])
final.head(13)
# Out:
#                  election voted
# voter_id
# 11001     Nov 18 Election     Y
# 11001     Nov 17 Election     Y
# 11001     Nov 16 Election     Y
# 11001     Nov 15 Election     Y
# 11001     Nov 14 Election     Y
# 11001     Nov 13 Election     Y
# 11001     Nov 12 Election     Y
# 11001     Nov 11 Election     Y
# 11001     Nov 10 Election     Y
# 11001     Nov 09 Election     Y
# 11001     Nov 08 Election     Y
# 11001     Nov 07 Election     Y
# 11001     Nov 06 Election     Y

# %%
final.to_csv('Elections.csv')
